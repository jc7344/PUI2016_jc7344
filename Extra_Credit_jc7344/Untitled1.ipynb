# %%
# %matplotlib inline
from __future__  import print_function, division
import numpy as np
from math import *
import pandas as pd
from pandas import DataFrame
from pandas.tools.plotting import scatter_matrix
from geopandas import GeoDataFrame
#import matplotlib.pylab as plt
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import geopandas as gp
import zipfile
import glob
import pylab as pl
import statsmodels.api as sm
import os

# %%
SAT = pd.read_csv(os.getenv("PUIDATA")+ "/" + 'SAT_Results .csv')

# %%
SAT.head()
# Out:
#       DBN                                    SCHOOL NAME  \
# 0  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1  01M448            UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2  01M450                     EAST SIDE COMMUNITY SCHOOL
# 3  01M458                      FORSYTH SATELLITE ACADEMY
# 4  01M509                        MARTA VALLE HIGH SCHOOL
#
#    SAT Critical Reading Avg. Score  SAT Math Avg. Score  \
# 0                              355                  404
# 1                              383                  423
# 2                              377                  402
# 3                              414                  401
# 4                              390                  433
#
#    SAT Writing Avg. Score
# 0                     363
# 1                     366
# 2                     370
# 3                     359
# 4                     384

# %%
SAT.head()
# Out:
#       DBN                                    SCHOOL NAME  \
# 0  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1  01M448            UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2  01M450                     EAST SIDE COMMUNITY SCHOOL
# 3  01M458                      FORSYTH SATELLITE ACADEMY
# 4  01M509                        MARTA VALLE HIGH SCHOOL
#
#    SAT Critical Reading Avg. Score  SAT Math Avg. Score  \
# 0                              355                  404
# 1                              383                  423
# 2                              377                  402
# 3                              414                  401
# 4                              390                  433
#
#    SAT Writing Avg. Score
# 0                     363
# 1                     366
# 2                     370
# 3                     359
# 4                     384

# %%
SAT['SAT Total'] = SAT['SAT Critical Reading Avg. Score'] + SAT['SAT Math Avg. Score'] + SAT['SAT Writing Avg. Score']

# %%
SAT.head()
# Out:
#       DBN                                    SCHOOL NAME  \
# 0  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1  01M448            UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2  01M450                     EAST SIDE COMMUNITY SCHOOL
# 3  01M458                      FORSYTH SATELLITE ACADEMY
# 4  01M509                        MARTA VALLE HIGH SCHOOL
#
#    SAT Critical Reading Avg. Score  SAT Math Avg. Score  \
# 0                              355                  404
# 1                              383                  423
# 2                              377                  402
# 3                              414                  401
# 4                              390                  433
#
#    SAT Writing Avg. Score  SAT Total
# 0                     363       1122
# 1                     366       1172
# 2                     370       1149
# 3                     359       1174
# 4                     384       1207

# %%
obs = SAT['SAT Total']

# %%
obs.std()
# Out:
# 174.53612282892178

# %%
print(len(SAT))
# Out:
# 421

# %%
obs.mean()
# Out:
# 1208.2042755344419

# %%
top_per = SAT[SAT['SAT Total']> (1208.2 + 174.5)]
top_per
# Out:
#         DBN                                        SCHOOL NAME  \
# 6    01M539  NEW EXPLORATIONS INTO SCIENCE, TECHNOLOGY AND ...
# 8    01M696                     BARD HIGH SCHOOL EARLY COLLEGE
# 21   02M376                                        NYC ISCHOOL
# 23   02M400              HIGH SCHOOL FOR ENVIRONMENTAL STUDIES
# 24   02M407              INSTITUTE FOR COLLABORATIVE EDUCATION
# 25   02M408           PROFESSIONAL PERFORMING ARTS HIGH SCHOOL
# 26   02M411                  BARUCH COLLEGE CAMPUS HIGH SCHOOL
# 27   02M412        N.Y.C. LAB SCHOOL FOR COLLABORATIVE STUDIES
# 28   02M413                   SCHOOL OF THE FUTURE HIGH SCHOOL
# 29   02M414                               N.Y.C. MUSEUM SCHOOL
# 30   02M416                      ELEANOR ROOSEVELT HIGH SCHOOL
# 31   02M418                             MILLENNIUM HIGH SCHOOL
# 41   02M475                             STUYVESANT HIGH SCHOOL
# 44   02M519                       TALENT UNLIMITED HIGH SCHOOL
# ...

# %%
print(len(top_per))
# Out:
# 50

# %%
SAT1 = pd.read_csv(os.getenv("PUIDATA")+ "/" + 'SAT_Results .csv')

# %%
print(len(SAT1))
# Out:
# 421

# %%
SAT1['SAT Total'] = SAT1['SAT Critical Reading Avg. Score'] + SAT1['SAT Math Avg. Score'] + SAT1['SAT Writing Avg. Score']

# %%
high_per = SAT1[SAT1['SAT Total']< (1208.2 + 174.5)]
high_per
# Out:
#         DBN                                        SCHOOL NAME  \
# 0    01M292      HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1    01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2    01M450                         EAST SIDE COMMUNITY SCHOOL
# 3    01M458                          FORSYTH SATELLITE ACADEMY
# 4    01M509                            MARTA VALLE HIGH SCHOOL
# 5    01M515            LOWER EAST SIDE PREPARATORY HIGH SCHOOL
# 7    01M650                               CASCADES HIGH SCHOOL
# 9    02M047  47 THE AMERICAN SIGN LANGUAGE AND ENGLISH SECO...
# 10   02M288                       FOOD AND FINANCE HIGH SCHOOL
# 11   02M294                               ESSEX STREET ACADEMY
# 12   02M296              HIGH SCHOOL OF HOSPITALITY MANAGEMENT
# 13   02M298                                   PACE HIGH SCHOOL
# 14   02M300  URBAN ASSEMBLY SCHOOL OF DESIGN AND CONSTRUCTI...
# 15   02M303                         FACING HISTORY SCHOOL, THE
# ...

# %%
print(len(high_per))
# Out:
# 371

# %%
os.system("high_per" + os.getenv("PUIDATA"))
# Out:
# 32512
