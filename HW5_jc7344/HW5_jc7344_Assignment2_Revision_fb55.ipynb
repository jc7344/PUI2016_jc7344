# %% [markdown]
# # FBB I do not know how this notebook compares to the rest of your work but this concerns me: the work is incomplete, but also it is not well described, or commented, there are bugs in the code that have not  been solved and therefore the code does not run, which means one of the plots does not even render.
#
# # Please be more careful in the midterm!

# %%
from __future__ import print_function, division
import sys
import os
import numpy as np
import pylab as pl
import pandas as pd

import json

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
url = "http://cosmo.nyu.edu/~fb55/PUI2016/data/"
keys = ['all', 'white', 'black', 'asian', 'hisp']
data_m = ['pinc08_2_1_1.xls', 'pinc08_2_1_4.xls', 'pinc08_2_1_6.xls', 'pinc08_2_1_8.xls', 'pinc08_2_1_9.xls']
all_males ={}

def male_income(key, data):
    for i in range(0, len(keys)): 
        all_males[key[i]] = pd.read_excel(url + data_m[i], header = 9)
male_income(keys, data_m)

# %%
all_males['white'].head()
# Out:
#               Characteristic  Total with Income  $1 to $2,499 or loss  \
# 0                        NaN                NaN                   NaN
# 1                  ....Total            73333.0                2913.0
# 2                   Earnings            55244.0                2195.0
# 3         ..Wages and Salary            51442.0                1859.0
# 4  ..Nonfarm Self-Employment             4970.0                1041.0
#
#    $2,500 to $4,999  $5,000 to $7,499  $7,500 to $9,999  $10,000 to $12,499  \
# 0               NaN               NaN               NaN                 NaN
# 1            1564.0            1632.0            2092.0              2479.0
# 2            1490.0            1480.0            1092.0              1830.0
# 3            1382.0            1407.0             976.0              1575.0
# 4             204.0             221.0             157.0               397.0
#
#    $12,500 to $14,999  $15,000 to $17,499  $17,500 to $19,999  \
# 0                 NaN                 NaN                 NaN
# 1              1933.0              2930.0              2298.0
# 2               771.0              1752.0               937.0
# 3               671.0              1575.0               866.0
# 4                96.0               236.0                89.0
#
#         ...         $92,500 to $94,999  $95,000 to $97,499  \
# 0       ...                        NaN                 NaN
# 1       ...                      411.0               493.0
# 2       ...                      198.0               452.0
# 3       ...                      197.0               436.0
# 4       ...                        0.0                14.0
#
#    $97,500 to $99,999  $100,000 and over  Median income  \
# 0                 NaN                NaN  Value\n(Dol.)
# 1               357.0             9669.0          40122
# 2               181.0             8048.0          44882
# 3               181.0             7459.0          45554
# 4                 0.0              413.0          20445
#
#               Unnamed: 44    Mean income             Unnamed: 46  Gini ratio  \
# 0  Standard\nerror (Dol.)  Value\n(Dol.)  Standard\nerror (Dol.)       Ratio
# 1                     274          56368                     593       0.493
# 2                     597          60075                     707       0.483
# 3                     309          60447                     744       0.476
# 4                     864          35925                    1622       0.631
#
#        Unnamed: 48
# 0  Standard\nerror
# 1           0.0038
# 2           0.0046
# 3           0.0049
# 4           0.0099
#
# [5 rows x 49 columns]

# %%
data_f = ['pinc08_3_1_1.xls', 'pinc08_3_1_4.xls', 'pinc08_3_1_6.xls', 'pinc08_3_1_8.xls', 'pinc08_3_1_9.xls']
all_females ={}

def female_income(key, data):
    for i in range(0, len(keys)): 
        all_females[key[i]] = pd.read_excel(url + data_f[i], header = 9)
female_income(keys, data_f)

# %%
all_females['all'].head()
# Out:
#               Characteristic  Total with Income  $1 to $2,499 or loss  \
# 0                        NaN                NaN                   NaN
# 1                  ....Total           109956.0                7590.0
# 2                   Earnings            74545.0                4198.0
# 3         ..Wages and Salary            71220.0                3835.0
# 4  ..Nonfarm Self-Employment             4694.0                1282.0
#
#    $2,500 to $4,999  $5,000 to $7,499  $7,500 to $9,999  $10,000 to $12,499  \
# 0               NaN               NaN               NaN                 NaN
# 1            4298.0            5557.0            7874.0              8052.0
# 2            3118.0            3269.0            2662.0              4579.0
# 3            2954.0            3005.0            2411.0              4309.0
# 4             288.0             410.0             253.0               388.0
#
#    $12,500 to $14,999  $15,000 to $17,499  $17,500 to $19,999  \
# 0                 NaN                 NaN                 NaN
# 1              5720.0              6768.0              4377.0
# 2              1994.0              4134.0              2585.0
# 3              1941.0              3908.0              2484.0
# 4                84.0               265.0               126.0
#
#         ...         $92,500 to $94,999  $95,000 to $97,499  \
# 0       ...                        NaN                 NaN
# 1       ...                      167.0               285.0
# 2       ...                       60.0               236.0
# 3       ...                       61.0               233.0
# 4       ...                        0.0                 0.0
#
#    $97,500 to $99,999  $100,000 and over  Median income  \
# 0                 NaN                NaN  Value\n(Dol.)
# 1               184.0             4442.0          22063
# 2               127.0             3535.0          27736
# 3               126.0             3370.0          28402
# 4                 0.0              127.0          10732
#
#               Unnamed: 44    Mean income             Unnamed: 46  Gini ratio  \
# 0  Standard\nerror (Dol.)  Value\n(Dol.)  Standard\nerror (Dol.)       Ratio
# 1                     137          31968                     250       0.495
# 2                     364          36189                     307       0.466
# 3                     379          36412                     316       0.461
# 4                     399          20942                    1123        0.65
#
#        Unnamed: 48
# 0  Standard\nerror
# 1           0.0025
# 2           0.0032
# 3           0.0032
# 4           0.0162
#
# [5 rows x 49 columns]

# %%
type(all_males)
# Out:
# dict

# %%
type(all_females)
# Out:
# dict

# %%
all_females['all'].columns
# Out:
# Index([      u'Characteristic',    u'Total with Income',
#        u'$1 to $2,499 or loss',     u'$2,500 to $4,999',
#            u'$5,000 to $7,499',     u'$7,500 to $9,999',
#          u'$10,000 to $12,499',   u'$12,500 to $14,999',
#          u'$15,000 to $17,499',   u'$17,500 to $19,999',
#          u'$20,000 to $22,499',   u'$22,500 to $24,999',
#          u'$25,000 to $27,499',   u'$27,500 to $29,999',
#          u'$30,000 to $32,499',   u'$32,500 to $34,999',
#          u'$35,000 to $37,499',   u'$37,500 to $39,999',
#          u'$40,000 to $42,499',   u'$42,500 to $44,999',
#          u'$45,000 to $47,499',   u'$47,500 to $49,999',
#          u'$50,000 to $52,499',   u'$52,500 to $54,999',
#          u'$55,000 to $57,499',   u'$57,500 to $59,999',
#          u'$60,000 to $62,499',   u'$62,500 to $64,999',
#          u'$65,000 to $67,499',   u'$67,500 to $69,999',
#          u'$70,000 to $72,499',   u'$72,500 to $74,999',
#          u'$75,000 to $77,499',   u'$77,500 to $79,999',
#          u'$80,000 to $82,499',   u'$82,500 to $84,999',
#          u'$85,000 to $87,499',   u'$87,500 to $89,999',
#          u'$90,000 to $92,499',   u'$92,500 to $94,999',
#          u'$95,000 to $97,499',   u'$97,500 to $99,999',
#           u'$100,000 and over',        u'Median income',
#                 u'Unnamed: 44',          u'Mean income',
#                 u'Unnamed: 46',           u'Gini ratio',
#                 u'Unnamed: 48'],
#       dtype='object')

# %%
for k,v in all_females.items():
    print("#####", k)
    print(v.describe())
for k,v in all_males.items():
    print("#####", k)
    print(v.describe())
# Out:
# ##### hisp
#        Total with Income  $1 to $2,499 or loss  $2,500 to $4,999  \
# count          46.000000             46.000000         46.000000
# mean         1908.739130            274.282609        137.717391
# std          3688.718088            568.547923        199.157298
# min             1.000000              0.000000          0.000000
# 25%                  NaN                   NaN               NaN
# 50%                  NaN                   NaN               NaN
# 75%                  NaN                   NaN               NaN
# max         14034.000000           2704.000000        783.000000
#
#        $5,000 to $7,499  $7,500 to $9,999  $10,000 to $12,499  \
# count         46.000000         46.000000           46.000000
# mean
# min            0.000000          0.000000            0.000000
# 25%                 NaN               NaN                 NaN
# 50%                 NaN               NaN                 NaN
# 75%                 NaN               NaN                 NaN
# max         1831.000000       2092.000000         2814.000000
#
#        $12,500 to $14,999  $15,000 to $17,499  $17,500 to $19,999  \
# count           46.000000           46.000000           46.000000
# mean           508.543478          663.652174          561.543478
# std            818.433129         1087.204922          980.180884
# min              0.000000            0.000000            0.000000
# 25%                   NaN                 NaN                 NaN
# 50%                   NaN                 NaN                 NaN
# 75%                   NaN                 NaN                 NaN
# max           2558.000000         3966.000000         3309.000000
#
#        $20,000 to $22,499        ...          $77,500 to $79,999  \
# count           46.000000        ...                   46.000000
# mean           590.586957        ...                   41.021739
# std            993.967976        ...                  110.100457
# min              0.000000        ...                    0.000000
# 25%                   NaN        ...                         NaN
# 50%                   NaN        ...                         NaN
# 75%                   NaN        ...                         NaN
# max           3661.000000        ...                  519.000000
#
#        $80,000 to $82,499  $82,500 to $84,999  $85,000 to $87,499  \
# count           46.000000           46.000000           46.000000
# mean           153.478261           37.000000           84.043478
# std            415.118818           93.901367          231.584106
# min              0.000000            0.000000            0.000000
# 25%                   NaN                 NaN                 NaN
# 50%                   NaN                 NaN                 NaN
# 75%                   NaN                 NaN                 NaN
# max           1431.000000          432.000000          812.000000
#
#        $87,500 to $89,999  $90,000 to $92,499  $92,500 to $94,999  \
# count           46.000000           46.000000           46.000000
# mean            31.326087          100.565217           30.173913
# std             81.833178          277.303095           84.575359
# min              0.000000            0.000000            0.000000
# 25%                   NaN                 NaN                 NaN
# 50%                   NaN                 NaN                 NaN
# 75%                   NaN                 NaN                 NaN
# max            333.000000          917.000000          411.000000
#
#        $95,000 to $97,499  $97,500 to $99,999  $100,000 and over
# count           46.000000           46.000000          46.000000
# mean            51.021739           51.217391         943.347826
# std            145.189453           82.877396        2638.025813
# min              0.000000            0.000000           0.000000
# 25%                   NaN                 NaN                NaN
# 50%                   NaN                 NaN                NaN
# 75%                   NaN                 NaN                NaN
# max            493.000000          357.000000        9669.000000
#
# [8 rows x 42 columns]
# ##### asian
#        Total with Income  $1 to $2,499 or loss  $2,500 to $4,999  \
# count          46.000000             46.000000         46.000000
# mean          829.956522            133.847826         35.782609
# std          1601.936009            422.415434         49.986182
# min             0.000000              0.000000          0.000000
# 25%                  NaN                   NaN               NaN
# 50%                  NaN                   NaN               NaN
# 75%                  NaN                   NaN               NaN
# max          5752.000000           2075.000000        159.000000
#
#        $5,000 to $7,499  $7,500 to $9,999  $10,000 to $12,499  \
# count         46.000000         46.000000           46.000000
# mean          34.304348         35.152174           39.434783
# std           51.598824         49.727688           60.445624
# min            0.000000          0.000000            0.000000
# 25%                 NaN               NaN                 NaN
# 50%                 NaN               NaN                 NaN
# 75%                 NaN               NaN                 NaN
# max          227.000000        195.000000          216.000000
#
#        $12,500 to $14,999  $15,000 to $17,499  $17,500 to $19,999  \
# count           46.000000           46.000000           46.000000
# mean            27.282609           32.521739           30.347826
# std             47.513115           63.901570           56.939819
# min              0.000000            0.000000            0.000000
# 25%                   NaN                 NaN                 NaN
# 50%                   NaN                 NaN                 NaN
# 75%                   NaN                 NaN                 NaN
# max            193.000000          238.000000          218.000000
#
#        $20,000 to $22,499        ...          $77,500 to $79,999  \
# count           46.000000        ...                   46.000000
# mean            26.695652        ...                    2.826087
# std             52.321175        ...                    7.860745
# min              0.000000        ...                    0.000000
# 25%                   NaN        ...                         NaN
# 50%                   NaN        ...                         NaN
# 75%                   NaN        ...                         NaN
# max            193.000000        ...                   28.000000
#
#        $80,000 to $82,499  $82,500 to $84,999  $85,000 to $87,499  \
# count           46.000000           46.000000           46.000000
# mean            11.869565            3.956522            5.543478
# std             33.027671           10.656154           16.082712
# min              0.000000            0.000000            0.000000
# 25%                   NaN                 NaN                 NaN
# 50%                   NaN                 NaN                 NaN
# 75%                   NaN                 NaN                 NaN
# max            109.000000           38.000000           54.000000
#
#        $87,500 to $89,999  $90,000 to $92,499  $92,500 to $94,999  \
# count           46.000000           46.000000           46.000000
# mean             1.543478           10.500000            3.152174
# std              4.815284           30.400841            9.140794
# min              0.000000            0.000000            0.000000
# 25%                   NaN                 NaN                 NaN
# 50%                   NaN                 NaN                 NaN
# 75%                   NaN                 NaN                 NaN
# max             24.000000           97.000000           32.000000
#
#        $95,000 to $97,499  $97,500 to $99,999  $100,000 and over
# count           46.000000           46.000000          46.000000
# mean             3.391304            2.978261          94.108696
# std              9.940888            6.977708         268.500712
# min              0.000000            0.000000           0.000000
# 25%                   NaN                 NaN                NaN
# 50%                   NaN                 NaN                NaN
# 75%                   NaN                 NaN                NaN
# max             40.000000           23.000000         904.000000
#
# [8 rows x 42 columns]

# %%
print (all_males['asian'].shape)
all_males['asian'].applymap(np.isreal).sum()
# Out:
# (49, 49)
# Characteristic           1
# Total with Income       49
# $1 to $2,499 or loss    49
# $2,500 to $4,999        49
# $5,000 to $7,499        49
# $7,500 to $9,999        49
# $10,000 to $12,499      49
# $12,500 to $14,999      49
# $15,000 to $17,499      49
# $17,500 to $19,999      49
# $20,000 to $22,499      49
# $22,500 to $24,999      49
# $25,000 to $27,499      49
# $27,500 to $29,999      49
# $30,000 to $32,499      49
# $32,500 to $34,999      49
# $35,000 to $37,499      49
# $37,500 to $39,999      49
# $40,000 to $42,499      49
# $42,500 to $44,999      49
# $45,000 to $47,499      49
# $47,500 to $49,999      49
# $50,000 to $52,499      49
# $52,500 to $54,999      49
# $55,000 to $57,499      49
# $57,500 to $59,999      49
# $60,000 to $62,499      49
# $62,500 to $64,999      49
# $65,000 to $67,499      49
# $67,500 to $69,999      49
# $70,000 to $72,499      49
# $72,500 to $74,999      49
# $75,000 to $77,499      49
# $77,500 to $79,999      49
# $80,000 to $82,499      49
# $82,500 to $84,999      49
# $85,000 to $87,499      49
# $87,500 to $89,999      49
# $90,000 to $92,499      49
# $92,500 to $94,999      49
# $95,000 to $97,499      49
# $97,500 to $99,999      49
# $100,000 and over       49
# Median income           28
# Unnamed: 44             28
# Mean income             28
# Unnamed: 46             28
# Gini ratio              28
# Unnamed: 48             28
# dtype: int64

# %%
for gender in [all_males, all_females]:
    for k in gender:
        # find non real values in the dataframe with applymap
        isreal  = gender[k].applymap(np.isreal)
        for c in gender[k].columns :
            #if some but not all values in column are real
            #replace the non real ones
            if isreal.sum()[c] > 0 and \
            isreal.sum()[c] < gender[k].shape[0]:
                gender[k][c][~isreal[c]] =  np.nan
                gender[k][c] = gender[k][c].astype(float)
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/ipykernel/__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
fig = pd.scatter_matrix(all_males['all']
                   [[u'Total with Income',u'$2,500 to $4,999',
                     u'Median income',u'Gini ratio']],
                   linewidth= 3, s=500, figsize=(15,15), 
                        diagonal='kde')
#Here we are plotting all males = total income, 2,500 to 4,999, median income and gini ratio.

# %% [markdown]
# # FBB missing figure caption.

# %%
fig2 = pd.scatter_matrix(all_females['all']
                   [[u'Total with Income',u'$2,500 to $4,999',
                     u'Median income',u'Gini ratio']],
                   linewidth= 3, s=500, figsize=(15,15), 
                        diagonal='kde') 
#Here we are plotting all females = total income, 2,500 to 4,999, median income and gini ratio.

# %%
all_females['all'].columns
# Out:
# Index([      u'Characteristic',    u'Total with Income',
#        u'$1 to $2,499 or loss',     u'$2,500 to $4,999',
#            u'$5,000 to $7,499',     u'$7,500 to $9,999',
#          u'$10,000 to $12,499',   u'$12,500 to $14,999',
#          u'$15,000 to $17,499',   u'$17,500 to $19,999',
#          u'$20,000 to $22,499',   u'$22,500 to $24,999',
#          u'$25,000 to $27,499',   u'$27,500 to $29,999',
#          u'$30,000 to $32,499',   u'$32,500 to $34,999',
#          u'$35,000 to $37,499',   u'$37,500 to $39,999',
#          u'$40,000 to $42,499',   u'$42,500 to $44,999',
#          u'$45,000 to $47,499',   u'$47,500 to $49,999',
#          u'$50,000 to $52,499',   u'$52,500 to $54,999',
#          u'$55,000 to $57,499',   u'$57,500 to $59,999',
#          u'$60,000 to $62,499',   u'$62,500 to $64,999',
#          u'$65,000 to $67,499',   u'$67,500 to $69,999',
#          u'$70,000 to $72,499',   u'$72,500 to $74,999',
#          u'$75,000 to $77,499',   u'$77,500 to $79,999',
#          u'$80,000 to $82,499',   u'$82,500 to $84,999',
#          u'$85,000 to $87,499',   u'$87,500 to $89,999',
#          u'$90,000 to $92,499',   u'$92,500 to $94,999',
#          u'$95,000 to $97,499',   u'$97,500 to $99,999',
#           u'$100,000 and over',        u'Median income',
#                 u'Unnamed: 44',          u'Mean income',
#                 u'Unnamed: 46',           u'Gini ratio',
#                 u'Unnamed: 48'],
# 24              38.0              32.0                31.0
# 25              50.0              11.0                63.0
# 26             111.0              59.0                55.0
# 27             774.0             586.0               525.0
# 28             513.0             361.0               221.0
# 29              71.0              27.0                35.0
# 30               3.0               3.0                35.0
# 31             167.0             183.0               193.0
# 32               4.0               8.0                 0.0
# 33              11.0               2.0                10.0
# 34              28.0              37.0                39.0
# 35             721.0             341.0               210.0
# 36            1227.0             300.0               404.0
# 37             223.0              60.0               174.0
# 38              40.0              28.0                29.0
# 39               NaN               NaN                 NaN
# 40            5434.0            7029.0              8704.0
# 41            5211.0            6739.0              8107.0
# 42            2752.0            5255.0              5035.0
# 43            2722.0            5030.0              4526.0
# 44            4185.0            6701.0              5534.0
# 45             614.0            1436.0               275.0
# 46            3091.0            6586.0              5412.0
# 47            1661.0            2269.0              1049.0
# 48               NaN               NaN                 NaN
#
#     $12,500 to $14,999  $15,000 to $17,499  $17,500 to $19,999     ...       \
# 0                  NaN                 NaN                 NaN     ...
# 1               5720.0              6768.0              4377.0     ...
# 2               1994.0              4134.0              2585.0     ...
# 3               1941.0              3908.0              2484.0     ...
# 4                 84.0               265.0               126.0     ...
# 5                  4.0                 4.0                 0.0     ...
# 6               4252.0              2990.0              1924.0     ...
# 7                130.0                72.0                30.0     ...
# 8                 17.0                 5.0                 3.0     ...
# 9                113.0                49.0                31.0     ...
# 10               183.0               113.0                82.0     ...
# 11                55.0                32.0                28.0     ...
# 12                98.0                69.0                56.0     ...
# 13                48.0                 8.0                 0.0     ...
# 14               474.0               520.0               232.0     ...
# 15               200.0               224.0                61.0     ...
# 16               140.0               144.0                61.0     ...
# 17               100.0               184.0                51.0     ...
# 18               697.0               455.0               416.0     ...
# 19               295.0               181.0               152.0     ...
# 20                65.0                39.0                36.0     ...
# 21                64.0                37.0                 1.0     ...
# 22               188.0               148.0               153.0     ...
# 23                36.0                11.0                 0.0     ...
# 24                20.0                19.0                26.0     ...
# 25                36.0                14.0                12.0     ...
# 26                13.0                 9.0                25.0     ...
# 27               475.0               320.0               302.0     ...
# 28               239.0               156.0               122.0     ...
# 29                43.0                21.0                22.0     ...
# 30                 8.0                20.0                 1.0     ...
# 31               164.0               125.0               142.0     ...
# 32                21.0                 5.0                 0.0     ...
# 33                 2.0                 0.0                17.0     ...
# 34                 2.0                13.0                20.0     ...
# 35               106.0                34.0                52.0     ...
# 36               120.0               156.0                34.0     ...
# 37                57.0                23.0                21.0     ...
# 38                10.0                22.0                 7.0     ...
# 39                 NaN                 NaN                 NaN     ...
# 40              5733.0              6797.0              4329.0     ...
# 41              5284.0              6358.0              4133.0     ...
# 42              4270.0              2990.0              1927.0     ...
# 43              3858.0              2638.0              1764.0     ...
# 44              4455.0              3114.0              2077.0     ...
# 45               169.0                84.0                41.0     ...
# 46              4443.0              3119.0              1998.0     ...
# 47               844.0               566.0               468.0     ...
# 48                 NaN                 NaN                 NaN     ...
#
#     $92,500 to $94,999  $95,000 to $97,499  $97,500 to $99,999  \
# 0                  NaN                 NaN                 NaN
# 1                167.0               285.0               184.0
# 2                 60.0               236.0               127.0
# 3                 61.0               233.0               126.0
# 4                  0.0                 0.0                 0.0
# 5                  0.0                 0.0                 0.0
# 6                  0.0                 0.0                 0.0
# 7                  0.0                 0.0                 0.0
# 8                  0.0                 0.0                 0.0
# 9                  0.0                 0.0                
# 40             3563.0        21159.0        129.0      31118.0        252.0
# 41             3666.0        22794.0        226.0      32170.0        255.0
# 42                0.0        11702.0         70.0      12475.0         72.0
# 43               29.0        12870.0        102.0      16540.0        157.0
# 44               32.0        10908.0         76.0      13179.0        112.0
# 45                0.0         6321.0        233.0       6359.0        119.0
# 46                0.0        11110.0         70.0      11890.0         67.0
# 47               10.0         8438.0        118.0      13092.0        245.0
# 48                NaN            NaN          NaN          NaN          NaN
#
#     Gini ratio  Unnamed: 48
# 0          NaN          NaN
# 1        0.495       0.0025
# 2        0.466       0.0032
# 3        0.461       0.0032
# 4        0.650       0.0162
# 5        0.916       0.0148
# 6        0.258       0.0025
# 7        0.315       0.0088
# 8        0.464       0.0139
# 9        0.420       0.0288
# 10       0.519       0.0140
# 11       0.515       0.0273
# 12       0.531       0.0143
# 13       0.644       0.0212
# 14       0.863       0.0025
# 15       0.893       0.0028
# 16       0.777       0.0065
# 17       0.743       0.0079
# 18       0.515       0.0055
# 19       0.532       0.0078
# 20       0.467       0.0162
# 21       0.431       0.0296
# 22       0.426       0.0088
# 23       0.304       0.0428
# 24       0.522       0.0287
# 25       0.515       0.0335
# 26       0.598       0.0249
# 27       0.516       0.0064
# 28       0.547       0.0082
# 29       0.437       0.0189
# 30       0.331       0.0276
# 31       0.418       0.0093
# 32       0.358       0.0600
# 33       0.604       0.0433
# 34       0.617       0.0277
# 35       0.513       0.0133
# 36       0.510       0.0108
# 37       0.604       0.0212
# 38       0.728       0.0381
# 39         NaN          NaN
# 40       0.482       0.0028
# 41       0.471       0.0027
# 42       0.259       0.0025
# 43       0.372       0.0032
# 44       0.387       0.0035
# 45       0.383       0.0083
# 46       0.277       0.0027
# 47       0.528       0.0048
# 48         NaN          NaN
#
# [49 rows x 49 columns]

# %% [markdown]
# # FBB there is no reason to show this much data! nobody is going to read these columns. Show the head, the tail, or a summary in your final version

# %%
#description

# %% [markdown]
# # FBB ... but there is no description, sigh...

# %%
m_white_inc = average(all_males['white'][[u'Median income']])
m_white_inc
# Out:
# nan

# %% [markdown]
# # FBB you should not leave printed outputs without explanation in your delivery ready notebook. Much less if the output is NaN! which means something is wrong... and you have not fixed it!

# %%
median = pl.scatter(all_males['white'][u'Median income'], all_females['white'][u'Median income'])

# %% [markdown]
# # FBB no caption or discussion or axis labels, title, legend...

# %%
all_females['all'].ix[2]['Median income']
# Out:
# 27736.0

# %% [markdown]
# # FBB another output without explanation

# %%
#median earnings
m_white_inc = all_males['white'].ix[2]['Median income']
f_white_inc = all_females['white'].ix[2]['Median income']
m_black_inc = all_males['black'].ix[2]['Median income']
f_black_inc = all_females['black'].ix[2]['Median income']
m_asian_inc = all_males['asian'].ix[2]['Median income']
f_asian_inc = all_females['asian'].ix[2]['Median income']
m_hisp_inc = all_males['hisp'].ix[2]['Median income']
f_hisp_inc = all_females['hisp'].ix[2]['Median income']

# %%
#m_inc = (m_white_inc, m_black_inc, m_asian_inc, m_hisp_inc)
#f_inc = (f_white_inc, f_black_inc, f_asian_inc, f_hisp_inc)

pl.figure(figsize = (6, 6))
pl.scatter(m_white_inc, f_white_inc, label = "White", color = 'blue')
pl.scatter(m_black_inc, f_black_inc, label = "Black", color = 'black')
pl.scatter(m_asian_inc, f_asian_inc, label = "Asian", color = 'red')
pl.scatter(m_hisp_inc, f_hisp_inc, label = "Hispanic", color = "green")
plt.axis([20000,50000,20000,50000])
plt.xlabel('Male Median Income ($)', fontsize = 12, fontweight = 'bold')
plt.ylabel('Female Median Income ($)', fontsize = 12, fontweight = 'bold')
t = plt.title('Gender Comparison of Median Income from Earnings by Race', fontsize = 14, fontweight = 'bold') 
t.set_y(1.05)
plt.legend(loc = 'upper left')
pl.plot([i for i in range(20000,50000)], [i for i in range(20000,50000)], color = 'black')

# %% [markdown]
# # FBB mising caption

# %%
# FBB move imports to the top
from scipy import stats

# %%
allmales=np.array([0., all_males['all']['Median income'][1],
                    all_males['white']['Median income'][1],
                    all_males['black']['Median income'][1],
                     all_males['hisp']['Median income'][1],
                    all_males['asian']['Median income'][1]])

allfemales=np.array([0.] + [all_females[k]['Median income'][1] \
                             for k in ['all', 'white', 'black',
                                     'hisp','asian']])
cor = stats.spearmanr(allmales, allfemales)
beta1 = cor[0] * allfemales.std() / allmales.std()
beta0 = allfemales.mean() - beta1 * allmales.mean()
beta0, beta1
#I was attempting to find both beta0 and beta1 in order to plot the line.
# Out:
# (2224.3609760454674, 0.57394829035421091)

# %%
xp = np.linspace(20000, 50000, 100)
pl.plot(xp, p(xp), '-', color = 'black')
pl.scatter(m_white_inc,f_white_inc, label = 'white', color = 'red')
pl.scatter(m_black_inc,f_black_inc, label = 'black', color = 'blue')
pl.scatter(m_asian_inc,f_asian_inc, label = 'asian', color = 'green')
pl.scatter(m_hisp_inc,f_hisp_inc, label = 'hisp', color = 'yellow')
pl.legend(loc = 'upper left')
pl.title('Gender Comparison of Median Income from Earnings by Race', fontsize = 14, fontweight = 'bold') 
pl.xlabel('Men ($)', fontsize = 12)
pl.ylabel('Women ($)', fontsize = 12)
pl.axis([20000, 50000, 20000, 50000])
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-27-facda4186e3b> in <module>()
#       1 xp = np.linspace(20000, 50000, 100)
# ----> 2 pl.plot(xp, p(xp), '-', color = 'black')
#       3 pl.scatter(m_white_inc,f_white_inc, label = 'white', color = 'red')
#       4 pl.scatter(m_black_inc,f_black_inc, label = 'black', color = 'blue')
#       5 pl.scatter(m_asian_inc,f_asian_inc, label = 'asian', color = 'green')
#
# NameError: name 'p' is not defined

# %% [markdown]
# # FBB why leave an error printed in your final version! First off this means the notebook does not run, so its 25% points lost. but also... celan up your notebook at least for presentation purposes even if you cannot fix a bug!

# %%
# FBB you already imported scipy. move imports to the top. You would have noticed if you did
from scipy import stats
slope, intercept, r_value, p_value, slope_std_error = stats.linregress(allmales, allfemales)
predictsal = intercept + slope * allmales

# %%
femalesal = intercept + slope * 120000
femalesal
# Out:
# 72935.913209241873

# %% [markdown]
# The Data tells us that given a man’s salary of $120,000, a woman will earn $72,956 which is 60% of the man's salary. This prediction could tell us than the disparity is larger than we initially thought.

# %% [markdown]
# # FBB formattin gissue. The data may tell you but you are not explaining how (i.e. you are not relating the slope of the regression to the 60%)
#
# # There is no discussion of race, se my solution for what you should have though of about that.
